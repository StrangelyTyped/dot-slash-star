# %%
import lightkurve as lk
pixelfile = lk.search_targetpixelfile("Trappist-1")[1].download()
# pixelfile = lk.search_targetpixelfile("Trappist-1", quarter=16).download()
# pixelfile = lk.search_targetpixelfile("KIC 8462852", quarter=16).download()
# pixelfile = lk.search_targetpixelfile("KIC 8462852")[1].download()
pixelfile.to_lightcurve(method="pld").remove_outliers().scatter()
# .remove_outliers().flatten()
# lc.to_periodogram("bls")
# period = lc.to_periodogram("bls").period_at_max_power
# period
# lc.fold(period).scatter()
#.tuncate(-0.5, -0.25).scatter()
# pixelfile.animate()
# Out:
# <AxesSubplot: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc.fold(period).scatter()
# Out:
# <AxesSubplot: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %%
from lightkurve import search_targetpixelfile
pixelfile = search_targetpixelfile("KIC 8462852", quarter=16).download()

# %%
lc = pixelfile.to_lightcurve(aperture_mask='all')
# Out:
# <AxesSubplot: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc.plot()
# Out:
# <AxesSubplot: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
